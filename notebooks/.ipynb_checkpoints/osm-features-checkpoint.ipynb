# %% [markdown]
# # Imports

# %%
from pyathena import connect
import pandas as pd
import numpy as np

from pathlib import Path 
current_path = Path().resolve()

RAW_PATH = current_path.parent / 'data' / 'raw'
OUTPUT_PATH = current_path.parent / 'data' / 'output'

# %matplotlib inline

# %% [markdown]
# # Connections

# %%
conn = connect(s3_staging_dir='s3://athena-fgv/staggin',
               region_name='us-east-2')

# %% [markdown]
# # OSM Data
#
# https://taginfo.openstreetmap.org/keys

# %%
sample = pd.read_sql_query('SELECT * FROM "osm"."california_district_3" limit 10;', conn)

# %%
sample.head(4)
# Out:
#            id  type tags        lat         lon nds members  changeset  \
# 0  1030979464  node   {}  39.636424 -120.012501  []      []    6605481
# 1  1030979570  node   {}  39.626327 -120.015171  []      []    6605536
# 2  1030979605  node   {}  39.634838 -119.963224  []      []    6605481
# 3  1030979617  node   {}  39.684711 -119.992431  []      []    6605481
#
#             timestamp    uid     user  version
# 0 2010-12-10 15:31:39  55774  nmixter        1
# 1 2010-12-10 15:31:42  55774  nmixter        1
# 2 2010-12-10 15:31:42  55774  nmixter        1
# 3 2010-12-10 15:31:42  55774  nmixter        1

# %%
update_log = pd.read_sql_query("""SELECT CAST(timestamp as date) as date,
count(*) as counta
FROM "osm"."california_district_3" 
GROUP BY CAST(timestamp as date)""", conn)

# %%
update_log.head(1)
# Out:
#          date  counta
# 0  2016-10-16     690

# %%
update_log.sort_values(by='date').plot(x='date')

# %% [markdown]
# # ADT data

# %%
adt = pd.read_parquet(RAW_PATH / 'pems_waze_features12.parquet')

# %%
adt = adt[['station', 'total_flow']].drop_duplicates().groupby('station').sum().sort_values(by='total_flow')

# %%
adt.head()
# Out:
#          total_flow
# station
# 312692          0.0
# 314621          0.0
# 314981          0.0
# 314618          0.0
# 318577          0.0

# %%
# adt = adt[adt['total_flow'] > 0]

# %%
adt[adt['total_flow'] > 0].hist(bins='fd')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x115fe7358>]],
#       dtype=object)

# %% [markdown]
# # Features
#
# The intent of OSM features is to get surrounding characteristics:
#
# 0. Overall
# 1. Urban x Rural
# 2. Residential x Comercial x Industrial
# 3. Places of Interest (POIs)
# 4. Recreational activity

# %%
query = """
SELECT 
  CAST(sensor_id AS BIGINT) as sensor_id,
  -- general features
  COUNT(*) as general_counta,
  COUNT (DISTINCT s.osm_id) as node_counta,
  COUNT (DISTINCT s.info) as info_counta,
  -- urban x rural
  SUM(CASE WHEN info = 'natural' THEN 1 ELSE 0 END) as natural_counta,
  SUM(CASE WHEN info = 'place' THEN 1 ELSE 0 END) as place_counta, -- place tags are mostly for small localities
  -- places of interest
  SUM(CASE WHEN info = 'amenity' THEN 1 ELSE 0 END) as amenity_counta,
  SUM(CASE WHEN info = 'school' THEN 1 ELSE 0 END) as school_counta,
  SUM(CASE WHEN info = 'restaurant' THEN 1 ELSE 0 END) as restaurant_counta,
  SUM(CASE WHEN info = 'post_box' THEN 1 ELSE 0 END) as post_box_counta,
  SUM(CASE WHEN info = 'place_of_worship' THEN 1 ELSE 0 END) as place_of_worship_counta,
  SUM(CASE WHEN info = 'shop' THEN 1 ELSE 0 END) as shop_counta
FROM "osm_pems"."osm_pems_ids" t
JOIN osm.california_district_3_open s
ON t.osm_id = s.osm_id
GROUP BY sensor_id
"""

# %%
features = pd.read_sql_query(query, con=conn)

# %%
features.head()
# Out:
#    sensor_id  general_counta  node_counta  info_counta  natural_counta  \
# 0     313835          948702        25278        10525             328
# 1     314969          548020        23797        10226             539
# 2     312520           65704         5015         3194             694
# 3     317830           29782         2490         1526             187
# 4     316783           17494         1774          937             770
#
#    place_counta  amenity_counta  school_counta  restaurant_counta  \
# 0            46            1973            125                477
# 1            34            2094            200                440
# 2            37            1785            297                152
# 3            22             648            127                 80
# 4            17             539              4                107
#
#    post_box_counta  place_of_worship_counta  shop_counta
# 0               12                      258          583
# 1               22                      431          624
# 2                9                      571          484
# 3                5                      150          199
# 4                4                       12          138

# %%
df = features.merge(adt, left_on='sensor_id', right_index=True)

# %% [markdown]
# # Simple Exploratory Analysis

# %%
df.columns
# Out:
# Index(['sensor_id', 'general_counta', 'node_counta', 'info_counta',
#        'natural_counta', 'natural_counta', 'amenity_counta', 'school_counta',
#        'restaurant_counta', 'post_box_counta', 'place_of_worship_counta',
#        'shop_counta', 'total_flow', 'hue'],
#       dtype='object')

# %%
import seaborn as sns
sns.set(style="ticks")

df['hue'] = 'all'

sns.pairplot(df[['general_counta', 'node_counta', 'info_counta', 'total_flow', 'hue']],
             hue='hue')

# %% [markdown]
# ## Introducing categories

# %%
adt[adt['total_flow'] > 0].apply(np.log10).hist(bins='fd')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11a0e2748>]],
#       dtype=object)

# %%
df['total_flow_log'] = df['total_flow'].apply(np.log10)

# %%
bins = pd.IntervalIndex.from_tuples([(0, 3), (3, 5), (5, 6)])
df['cats'] = pd.cut(df['total_flow_log'], bins, labels=['low', 'medium', 'high'])

# %%
df = df[df['total_flow'] > 0]

# %%
sns.pairplot(df[['general_counta', 'node_counta', 'info_counta', 'total_flow', 'cats']],
             hue='cats')

# %%
df.columns
# Out:
# Index(['sensor_id', 'general_counta', 'node_counta', 'info_counta',
#        'natural_counta', 'place_counta', 'amenity_counta', 'school_counta',
#        'restaurant_counta', 'post_box_counta', 'place_of_worship_counta',
#        'shop_counta', 'total_flow', 'total_flow_log', 'cats'],
#       dtype='object')

# %%
sns.pairplot(df[['natural_counta', 'place_counta', 'amenity_counta', 'total_flow', 'cats']],
             hue='cats')

# %%
sns_plot = sns.pairplot(df[['school_counta',
       'restaurant_counta', 'post_box_counta', 'place_of_worship_counta',
       'shop_counta', 'total_flow', 'cats']],
             hue='cats')
sns_plot.savefig(OUTPUT / 'image_amenities.png')

# %% [markdown]
# # Prepare Database

# %%
## First Analysis
